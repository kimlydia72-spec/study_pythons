# %%
first = "welcome sanghun!"

# %%
first
# Out:
# 'welcome sanghun!'

# %%
first = 'good day!'

# %%
first
# Out:
# 'good day!'

# %%
first = second

# %%
first
# Out:
# "Life is simple 'really?'"

# %%
second
# Out:
# "Life is simple 'really?'"

# %%
first = "welcome sanghun!"

# %%
third = "lift is " + 'good!'

# %%
third
# Out:
# 'lift is good!'

# %%
third = "lift is " + first

# %%
third
# Out:
# 'lift is welcome sanghun!'

# %%
second = "lift is good!"

# %%
third = first + " " + second

# %%
third
# Out:
# 'welcome sanghun! lift is good!'

# %% [markdown]
# ## 문제 풀이
# - 두 문자열 변수를 선언해서 각각 변수에 값을 넣고, + 기호를 이용해 이어 붙이는 코드를 작성해 보세요.
# - 변수 이름 : first, second, result
# - 결과) 'Good Morning'
