# %% [markdown]
# ## 단일 리스트

# %%
first = ['1', '2', '3', '4']

# %%
first
# Out:
# ['1', '2', '3', '4']

# %%
type(first)
# Out:
# list

# %%
first[2]
# Out:
# '3'

# %%
first[3]
# Out:
# '4'

# %%
first[0]
# Out:
# '1'

# %%
second = ['morning',
          'afternoon',
          'night']

# %%
second
# Out:
# ['morning', 'afternoon', 'night']

# %%
second[1]
# Out:
# 'afternoon'

# %%
night = 'night'

# %%
third = ['morning',
          'afternoon',
          night]

# %%
third
# Out:
# ['morning', 'afternoon', 'night']

# %% [markdown]
# ## 문제 풀이

# %% [markdown]
# ### 1번 문제
