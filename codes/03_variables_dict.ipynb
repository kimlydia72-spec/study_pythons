# %%
first = { "second" : "good" }

# %%
first
# Out:
# {'second': 'good'}

# %%
first["second"]
# Out:
# 'good'

# %%
second = {
    "first" : "good",
    "second" : "bad"
}

# %%
second["second"]
# Out:
# 'bad'

# %%
third = "not bad"

# %%
second = {
    "first" : "good",
    "second" : "bad",
    "not_key" : third
}

# %%
third = "good_key"

# %%
second
# Out:
# {'first': 'good', 'second': 'bad', 'not_key': 'not bad'}

# %%
second["not_key"]
# Out:
# 'not bad'
